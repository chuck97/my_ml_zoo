# %% [markdown]
# # Inspect IAEVALL03 dataset
#
# This notebook loads the dataset configuration, discovers variable files, and opens an example variable dataset with xarray.

# %%
from pathlib import Path
import sys
import importlib

repo_root = Path.cwd().resolve()
for candidate in [repo_root, *repo_root.parents]:
    if (candidate / 'src' / 'my_ml_zoo').exists():
        repo_root = candidate
        break
else:
    raise RuntimeError('Unable to locate repository root containing src/my_ml_zoo')

src_path = repo_root / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

importlib.invalidate_caches()
for module_name in [
    'my_ml_zoo.data',
    'my_ml_zoo',
    'my_ml_zoo.data.dataset_config',
    'my_ml_zoo.data.file_discovery',
    'my_ml_zoo.data.xarray_dataset',
]:
    if module_name in sys.modules:
        del sys.modules[module_name]

from my_ml_zoo.data import (
    DatasetConfig,
    discover_variable_files,
    select_variable_file,
    open_variable_dataset,
    infer_file_year,
)

# %%
config_path = repo_root / 'configs' / 'datasets' / 'iaevall03.json'
dataset_config = DatasetConfig.load_from_json(config_path)

print('Dataset name:', dataset_config.dataset_name)
print('Description:', dataset_config.description)
print('Base directory:', dataset_config.base_directory)
print('File format:', dataset_config.file_format)
print('Storage layout:', dataset_config.storage_layout)
print('Variables:', len(dataset_config.get_variable_names()))
print(dataset_config.get_variable_names())
# Out:
# Dataset name: IAEVALL03
# Description: ERA5-driven historical ICON-CLM regional climate model run over Europe
# Base directory: /work/bb1364/production_runs/work/IAEVALL03/yearly
# File format: ncz
# Storage layout: StorageLayout(variables_in_subdirectories=True, default_file_pattern='*.ncz')
# Variables: 11
# ['T_2M', 'TOT_PREC', 'ASOD_S', 'ACLCT', 'U_10M', 'V_10M', 'PMSL', 'HSURF', 'FR_LAND', 'HPBL', 'RELHUM_2M']

# %%
for variable_name in dataset_config.get_variable_names():
    variable_config = dataset_config.get_variable_config(variable_name)
    paths = discover_variable_files(dataset_config, variable_name)
    print(f'{variable_name}: {len(paths)} files')
    print('  temporal resolution:', variable_config.native_temporal_resolution)
    print('  sample:', paths[:5])
    if paths:
        if variable_config.is_static:
            print('  static variable: no time coordinate expected')
        try:
            inferred_year = infer_file_year(paths[0])
            print('  inferred sample file year:', inferred_year)
        except Exception as exc:
            print('  year inference skipped:', exc)
# Out:
# T_2M: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/T_2M/T_2M_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/T_2M/T_2M_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/T_2M/T_2M_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/T_2M/T_2M_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/T_2M/T_2M_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950
# TOT_PREC: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/TOT_PREC/TOT_PREC_1950010100-1951010100.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/TOT_PREC/TOT_PREC_1951010100-1952010100.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/TOT_PREC/TOT_PREC_1952010100-1953010100.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/TOT_PREC/TOT_PREC_1953010100-1954010100.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/TOT_PREC/TOT_PREC_1954010100-1955010100.ncz')]
#   inferred sample file year: 1950
# ASOD_S: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ASOD_S/ASOD_S_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ASOD_S/ASOD_S_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ASOD_S/ASOD_S_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ASOD_S/ASOD_S_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ASOD_S/ASOD_S_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950
# ACLCT: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ACLCT/ACLCT_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ACLCT/ACLCT_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ACLCT/ACLCT_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ACLCT/ACLCT_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/ACLCT/ACLCT_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950
# U_10M: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/U_10M/U_10M_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/U_10M/U_10M_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/U_10M/U_10M_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/U_10M/U_10M_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/U_10M/U_10M_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950
# V_10M: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/V_10M/V_10M_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/V_10M/V_10M_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/V_10M/V_10M_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/V_10M/V_10M_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/V_10M/V_10M_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950
# PMSL: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/PMSL/PMSL_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/PMSL/PMSL_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/PMSL/PMSL_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/PMSL/PMSL_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/PMSL/PMSL_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950
# HSURF: 1 files
#   temporal resolution: single_time_step
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/HSURF/HSURF.nc')]
#   static variable: no time coordinate expected
#   year inference skipped: Unable to infer year for file without time coordinate: /work/bb1364/production_runs/work/IAEVALL03/yearly/HSURF/HSURF.nc
# FR_LAND: 1 files
#   temporal resolution: single_time_step
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/FR_LAND/FR_LAND.nc')]
#   static variable: no time coordinate expected
#   year inference skipped: Unable to infer year for file without time coordinate: /work/bb1364/production_runs/work/IAEVALL03/yearly/FR_LAND/FR_LAND.nc
# HPBL: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/HPBL/HPBL_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/HPBL/HPBL_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/HPBL/HPBL_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/HPBL/HPBL_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/HPBL/HPBL_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950
# RELHUM_2M: 75 files
#   temporal resolution: hourly
#   sample: [PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/RELHUM_2M/RELHUM_2M_1950010100-1950123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/RELHUM_2M/RELHUM_2M_1951010100-1951123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/RELHUM_2M/RELHUM_2M_1952010100-1952123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/RELHUM_2M/RELHUM_2M_1953010100-1953123123.ncz'), PosixPath('/work/bb1364/production_runs/work/IAEVALL03/yearly/RELHUM_2M/RELHUM_2M_1954010100-1954123123.ncz')]
#   inferred sample file year: 1950

# %%
print('Opening T_2M dataset with xarray for a single year...')
selected_file = select_variable_file(dataset_config, 'T_2M')
selected_year = infer_file_year(selected_file)
print('Selected file:', selected_file.name)
print('Year to open:', selected_year)

ds_t2m = open_variable_dataset(dataset_config, 'T_2M', year=selected_year)
ds_t2m
# Out:
# Opening T_2M dataset with xarray for a single year...
# Selected file: T_2M_1950010100-1950123123.ncz
# Year to open: 1950
# <xarray.Dataset>
# Dimensions:       (time: 8760, height: 1, rlat: 412, rlon: 424, nv: 4)
# Coordinates:
#   * height        (height) float64 2.0
#     lat           (rlat, rlon) float32 ...
#     lon           (rlat, rlon) float32 ...
#   * rlat          (rlat) float32 -23.38 -23.26 -23.16 ... 21.61 21.73 21.83
#   * rlon          (rlon) float32 -28.38 -28.26 -28.16 ... 17.93 18.05 18.16
#   * time          (time) datetime64[ns] 1950-01-01 ... 1950-12-31T23:00:00
# Dimensions without coordinates: nv
# Data variables:
#     T_2M          (time, height, rlat, rlon) float32 ...
#     lat_bnds      (rlat, rlon, nv) float32 ...
#     lon_bnds      (rlat, rlon, nv) float32 ...
#     rotated_pole  |S1 ...
# Attributes: (12/16)
#     CDI:               Climate Data Interface version 2.4.0 (https://mpimet.m...
#     Conventions:       CF-1.4
#     source:            https://gitlab.dkrz.de/icon/icon-model.git@7016082e7bf...
#     institution:       CLMcom-ETH
#     title:             EURO-CORDEX 0.11 simulation with ICON-CLM and SPICE 2.3
#     history:           Mon Apr 28 21:45:09 2025: cdo -s -P 1 remap,/capstor/s...
#     ...                ...
#     realization:       1
#     ConventionsURL:    http://www.cfconventions.org/
#     contact:           support@c2sm.ethz.ch
#     icon-clm_version:  ICON-2024.07
#     creation_date:     2025-04-28 21:18:30 CEST
#     CDO:               Climate Data Operators version 2.4.0 (https://mpimet.m...

# %%
print('Opening HSURF static variable for the same year...')
selected_hsurf = select_variable_file(dataset_config, 'HSURF', year=selected_year)
print('HSURF file:', selected_hsurf.name)
ds_hsurf = open_variable_dataset(dataset_config, 'HSURF', year=selected_year)
ds_hsurf
# Out:
# Opening HSURF static variable for the same year...
# HSURF file: HSURF.nc
# <xarray.Dataset>
# Dimensions:       (rlat: 412, rlon: 424, nv: 4)
# Coordinates:
#     lat           (rlat, rlon) float32 ...
#     lon           (rlat, rlon) float32 ...
#   * rlat          (rlat) float32 -23.38 -23.26 -23.16 ... 21.61 21.73 21.83
#   * rlon          (rlon) float32 -28.38 -28.26 -28.16 ... 17.93 18.05 18.16
# Dimensions without coordinates: nv
# Data variables:
#     HSURF         (rlat, rlon) float32 ...
#     lat_bnds      (rlat, rlon, nv) float32 ...
#     lon_bnds      (rlat, rlon, nv) float32 ...
#     rotated_pole  |S1 ...
# Attributes: (12/20)
#     CDI:                        Climate Data Interface version 2.4.0 (https:/...
#     Conventions:                CF-1.4
#     uuidOfVGrid:                6da16f93-6445-ed9e-92a2-623f9e722ca0
#     source:                     https://gitlab.dkrz.de/icon/icon-model.git@8e...
#     institution:                CLMcom-ETH
#     references:                 see MPIM/DWD publications
#     ...                         ...
#     creation_date:              2025-12-03 16:42:47 CET
#     NCO:                        netCDF Operators version 5.1.9 (Homepage = ht...
#     history:                    Wed Dec 03 16:42:51 2025: cdo -s setmissval,-...
#     history_of_appended_files:  Wed Dec  3 16:42:49 2025: Appended file /caps...
#     rawdata:                    GLOBCOVER2009, HWSD2.0, MERIT, Lake Database
#     CDO:                        Climate Data Operators version 2.4.0 (https:/...
